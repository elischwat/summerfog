# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from PIL import Image
from IPython.display import display
# Out:
# /home/caprice/micromamba/envs/summerfog/lib/python3.12/site-packages/numpy/_core/getlimits.py:552: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %% [markdown]
# # Data from 2021 study:
# https://www.bco-dmo.org/dataset/920001 - 'CTD data from casts at Friday Harbor, WA in August of 2021 as part of a study of cold-water coral Balanophyllia elegans diet and trophic position'
#
#
# There were three casts:
# Station 1: 2021-08-02T19:31Z  48.5527272  -123.0060498
# Station 2: 2021-08-02T21:22Z	48.5460371	-123.0069808
# Station 3: 2021-08-03T09:11Z	48.5621039	-123.0137764

# %%
f1 = '/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/online data/s1_920001_v1_ctd.csv'
f2 = '/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/online data/s2_920001_v1_ctd.csv'
f3 = '/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/online data/s3_920001_v1_ctd.csv'

df1 = pd.read_csv(f1)
df2 = pd.read_csv(f2)
df3 = pd.read_csv(f3)

# %%
fig, ax = plt.subplots()

plt.plot(df1['Salinity'], df1['Depth'], label='Station 1 - 08/02 12:31pm', color='blue')
plt.plot(df2['Salinity'], df2['Depth'], label='Station 2 - 08/02 2:22pm', color='orange')
plt.plot(df3['Salinity'], df3['Depth'], label='Station 3 - 08/03 2:11am', color='green')


plt.xlabel('Salinity')
plt.ylabel('Depth (m)')
plt.legend()


ax.invert_yaxis()

# %% [markdown]
# # 07/09/2025 data
# 'A cloudy day'
# 9:30am - 7:30pm periodic (every hour-ish) CTD profiles taken off of the inside of the FHL dock. Outside of dock was also done, can see below.
# morning: low clouds, slight on-and-off drizzle until ~ 11am. no wind until 11:30ish
# afternoon: wind built through the afternoon and was still pretty gusty around 7:30pm. Clouds also lifted a little bit and we go some sunlight
# Overall, a cool day.
# I'm interested in comparing this profile to one from a sunnier, warmer day. Maybe other variations, too. A warm day should have a bigger difference between the top and bottom of the water column. Would the cooler extreme get shifted up at all?
# Also, what goes on when the tide goes from all the way up to all the way out?
# Also, what about a column of water not directly affected by a floating piece of cement?

# %%
fn1 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock930_20250709_163310.csv"
fn2 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1030_20250709_173440.csv"
fn3 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1130_20250709_183441.csv"
fn4 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1230_20250709_193628.csv"
fn5 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1330_20250709_203426.csv"
fn6 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1430_20250709_213428.csv"
fn7 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1530_20250709_223856.csv"
fn8 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1630_20250709_233143.csv"
fn9 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1800_20250710_005908.csv"
fn10 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1830_20250710_013632.csv"
fn11 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/inner dock/inner_dock1930_20250710_023724.csv"





f1 = pd.read_csv(fn1)
f2 = pd.read_csv(fn2)
f3 = pd.read_csv(fn3)
f4 = pd.read_csv(fn4)
f5 = pd.read_csv(fn5)
f6 = pd.read_csv(fn6)
f7 = pd.read_csv(fn7)
f8 = pd.read_csv(fn8)
f9 = pd.read_csv(fn9)
f10 = pd.read_csv(fn10)
f11 = pd.read_csv(fn11)

# %%
fig, ax = plt.subplots()

plt.plot(f1['Temperature (Celsius)'], f1['Depth (Meter)'], label='T (C) 9:30am', color='red')
plt.plot(f2['Temperature (Celsius)'], f2['Depth (Meter)'], label='T (C) 10:30am', color='orange')
plt.plot(f3['Temperature (Celsius)'], f3['Depth (Meter)'], label='T (C) 11:30am', color='yellow')
plt.plot(f4['Temperature (Celsius)'], f4['Depth (Meter)'], label='T (C) 12:30pm', color='green')
plt.plot(f5['Temperature (Celsius)'], f5['Depth (Meter)'], label='T (C) 1:30pm', color='cyan')
plt.plot(f6['Temperature (Celsius)'], f6['Depth (Meter)'], label='T (C) 2:30pm', color='blue')
plt.plot(f7['Temperature (Celsius)'], f7['Depth (Meter)'], label='T (C) 3:30pm', color='indigo')
plt.plot(f8['Temperature (Celsius)'], f8['Depth (Meter)'], label='T (C) 4:30pm', color='purple')
plt.plot(f9['Temperature (Celsius)'], f9['Depth (Meter)'], label='T (C) 6:00pm', color='magenta')
plt.plot(f10['Temperature (Celsius)'], f10['Depth (Meter)'], label='T (C) 6:30pm', color='pink')
plt.plot(f11['Temperature (Celsius)'], f11['Depth (Meter)'], label='T (C) 7:30pm', color='gray')
ax.invert_yaxis()
plt.grid()
plt.xlabel('Temperature (C) next to SST sensor')
plt.ylabel('Depth (m)')
plt.legend()



img = Image.open('/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/images/tide7.9.25.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1780x538>

# %%
fil1 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/outer_dock1230_20250709_193749.csv"
fil2 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/outer_dock_CC1313005_163505.csv"
fil3 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/outer_dock1030_CC1313005_20250709_173609.csv"
fil4 = "/mnt/c/Users/isabe/FILES/Documents/FHL Summer 2025/CTD data/processed data/07-09 experiment/outer_dock1130_20250709_183605.csv"
fil5 = 
fil6 = 


f1 = pd.read_csv(fil1)
f2 = pd.read_csv(fil2)
f3 = pd.read_csv(fil3)
f4 = pd.read_csv(fil4)

# %%
fig, ax = plt.subplots()

plt.plot(f1['Temperature (Celsius)'], f1['Depth (Meter)'], label='Temperature 9:30am', color='red')
plt.plot(f2['Temperature (Celsius)'], f2['Depth (Meter)'], label='Temperature 10:30am', color='orange')
plt.plot(f3['Temperature (Celsius)'], f3['Depth (Meter)'], label='Temperature 11:30am', color='yellow')
plt.plot(f4['Temperature (Celsius)'], f4['Depth (Meter)'], label='Temperature 12:30pm', color='green')

ax.invert_yaxis()
plt.xlabel('Temperature (C) across dock from SST sensor')
plt.ylabel('Depth (m)')
plt.legend()

# %%
fig, ax = plt.subplots()

plt.plot(f1['Salinity (Practical Salinity Scale)'], f1['Depth (Meter)'], label='T (C) 9:30am', color='red')
plt.plot(f2['Salinity (Practical Salinity Scale)'], f2['Depth (Meter)'], label='T (C) 10:30am', color='orange')
plt.plot(f3['Salinity (Practical Salinity Scale)'], f3['Depth (Meter)'], label='T (C) 11:30am', color='yellow')
plt.plot(f4['Salinity (Practical Salinity Scale)'], f4['Depth (Meter)'], label='T (C) 12:30pm', color='green')
plt.plot(f5['Salinity (Practical Salinity Scale)'], f5['Depth (Meter)'], label='T (C) 1:30pm', color='cyan')
plt.plot(f6['Salinity (Practical Salinity Scale)'], f6['Depth (Meter)'], label='T (C) 2:30pm', color='blue')
plt.plot(f7['Salinity (Practical Salinity Scale)'], f7['Depth (Meter)'], label='T (C) 3:30pm', color='indigo')
plt.plot(f8['Salinity (Practical Salinity Scale)'], f8['Depth (Meter)'], label='T (C) 4:30pm', color='purple')
plt.plot(f9['Salinity (Practical Salinity Scale)'], f9['Depth (Meter)'], label='T (C) 6:00pm', color='magenta')
plt.plot(f10['Salinity (Practical Salinity Scale)'], f10['Depth (Meter)'], label='T (C) 6:30pm', color='pink')
plt.plot(f11['Salinity (Practical Salinity Scale)'], f11['Depth (Meter)'], label='T (C) 7:30pm', color='gray')
ax.invert_yaxis()
plt.grid()
plt.xlabel('Salinity next to SST sensor')
plt.ylabel('Depth (m)')

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1780x538>
